# %%
from keras.models import load_model
import cv2

# %%
model=load_model("my_ANN.h5")

# %%
import numpy as np
from keras.preprocessing import image
test_image1=(image.load_img('output/test/video1/104_898.jpg',target_size=(64,64)))
test_image1=image.img_to_array(test_image)
gray=cv2.cvtColor(test_image1,cv2.COLOR_RGB2GRAY)

# %%
import matplotlib.pyplot as plt
path=cv2.imread("output/test/video1/104_898.jpg")
imgplot = plt.imshow(path)
plt.show()

result=model.predict(gray)
result= result.argmax(axis=1)
pred = int(np.mean(result))

if(pred==0 or pred==2 or pred==4):
    print("The Student Dont understand")
else:
    print("The Student is Okay")

if pred==0:
	print('feels angry')
elif pred==1:
	print('feels disgust')
elif pred==2:
	print('feels fear')
elif pred==3:
	print('feels happy')
elif pred==4:
	print('feels sad')
elif pred==5:
    print('feels surprise')
else:
	print('feels netural')
# Out:
# The Student Dont understand
# feels sad

# %%
test_image2=(image.load_img('output/test/video2/104_4.jpg',target_size=(64,64)))
test_image2=image.img_to_array(test_image2)
gray2=cv2.cvtColor(test_image2,cv2.COLOR_RGB2GRAY)
import matplotlib.pyplot as plt
path=cv2.imread("output/test/video2/104_4.jpg")
imgplot = plt.imshow(path)
plt.show()

result2=model.predict(gray2)
result2= result2.argmax(axis=1)
pred2 = int(np.mean(result2))

if(pred2==0 or pred2==2 or pred2==4):
    print("The Student Dont understand")
else:
    print("The Student is Okay")

if pred2==0:
	print('feels angry')
elif pred2==1:
	print('feels disgust')
elif pred2==2:
	print('feels fear')
elif pred2==3:
	print('feels happy')
elif pred2==4:
	print('feels sad')
elif pred2==5:
    print('feels surprise')
else:
	print('feels netural')
# Out:
# The Student Dont understand
# feels sad

# %%
test_image3=(image.load_img('output/test/video3/104_834.jpg',target_size=(64,64)))
test_image3=image.img_to_array(test_image3)
gray3=cv2.cvtColor(test_image3,cv2.COLOR_RGB2GRAY)
import matplotlib.pyplot as plt
path=cv2.imread("output/test/video3/104_834.jpg")
imgplot = plt.imshow(path)
plt.show()

result3=model.predict(gray3)
result3= result3.argmax(axis=1)
pred3 = int(np.mean(result3))

if(pred3==0 or pred3==2 or pred3==4):
    print("The Student Dont understand")
else:
    print("The Student is Okay")

if pred3==0:
	print('feels angry')
elif pred3==1:
	print('feels disgust')
elif pred3==2:
	print('feels fear')
elif pred3==3:
	print('feels happy')
elif pred3==4:
	print('feels sad')
elif pred3==5:
    print('feels surprise')
else:
	print('feels netural')
# Out:
# The Student is Okay
# feels surprise

# %%
test_image4=(image.load_img('output/test/video2/104_5.jpg',target_size=(64,64)))
test_image4=image.img_to_array(test_image4)
gray4=cv2.cvtColor(test_image4,cv2.COLOR_RGB2GRAY)
import matplotlib.pyplot as plt
path=cv2.imread("output/test/video2/104_5.jpg")
imgplot = plt.imshow(path)
plt.show()

result4=model.predict(gray4)
result4= result4.argmax(axis=1)
pred4 = int(np.mean(result4))

if(pred4==0 or pred4==2 or pred4==4):
    print("The Student Dont understand")
else:
    print("The Student is Okay")

if pred4==0:
	print('feels angry')
elif pred4==1:
	print('feels disgust')
elif pred4==2:
	print('feels fear')
elif pred4==3:
	print('feels happy')
elif pred4==4:
	print('feels sad')
elif pred4==5:
    print('feels surprise')
else:
	print('feels netural')
# Out:
# The Student is Okay
# feels happy
